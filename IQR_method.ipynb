# %% [markdown]
# <a href="https://colab.research.google.com/github/rutu019/MLT_practice/blob/main/IQR_method.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import seaborn as sns

# %%
data = [6, 2, 3, 4, 5, 1, 50]
sort_data = np.sort(data)
sort_data
# Out:
# array([ 1,  2,  3,  4,  5,  6, 50])

# %%
Q1 = np.percentile(data, 25, interpolation = 'midpoint')
Q2 = np.percentile(data, 50, interpolation = 'midpoint')
Q3 = np.percentile(data, 75, interpolation = 'midpoint')

print('Q1 25 percentile of the given data is, ', Q1)
print('Q1 50 percentile of the given data is, ', Q2)
print('Q1 75 percentile of the given data is, ', Q3)

IQR = Q3 - Q1
print('Interquartile range is', IQR)
# Out:
# Q1 25 percentile of the given data is,  2.5
# Q1 50 percentile of the given data is,  4.0
# Q1 75 percentile of the given data is,  5.5
# Interquartile range is 3.0

# %%
low_lim = Q1 - 1.5 * IQR
up_lim = Q3 + 1.5 * IQR
print('low_limit is', low_lim)
print('up_limit is', up_lim)
# Out:
# low_limit is -2.0
# up_limit is 10.0

# %%
outlier =[]
for x in data:
    if ((x> up_lim) or (x<low_lim)):
         outlier.append(x)
print(' outlier in the dataset is', outlier)
# Out:
#  outlier in the dataset is [50]

# %%
sns.boxplot(data)
# Out:
# <Axes: >
