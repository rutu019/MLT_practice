# %% [markdown]
# <a href="https://colab.research.google.com/github/rutu019/MLT_practice/blob/main/Introduction_to_numpy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
array_a = np.array([10,20,30,40,60])
array_b = np.array([1,3,4,6,2])
result = array_b * array_a
print("Multiplication of two arrays is : ",result)
# Out:
# Multiplication of two arrays is :  [ 10  60 120 240 120]

# %%
import pandas as pd
temperatures = pd.Series([28,30,45,31])
print(temperatures)
# Out:
# 0    28
# 1    30
# 2    45
# 3    31
# dtype: int64
